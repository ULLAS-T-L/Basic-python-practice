# %% [markdown]
# # MPG Cars

# %% [markdown]
# ### Introduction:
#
# The following exercise utilizes data from [UC Irvine Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Auto+MPG)
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the  datasets [cars1.csv](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/Merge/Auto_MPG/cars1.csv) and [cars2.csv](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/Merge/Auto_MPG/cars2.csv) from the folder

# %%
cars1 = pd.read_csv(r'C:\Users\prana\Desktop\Quarntine\AnalatyicsLab\Python\3._Case_Studies_Final_Projects_-_Python\2. Pandas Basic Exercises\Exercise Data Files\Pandas Exercise Simple Joins files\cars1.csv')
cars2 = pd.read_csv(r'C:\Users\prana\Desktop\Quarntine\AnalatyicsLab\Python\3._Case_Studies_Final_Projects_-_Python\2. Pandas Basic Exercises\Exercise Data Files\Pandas Exercise Simple Joins files\cars2.csv')

# %% [markdown]
#    ### Step 3. Assign each to a to a variable called cars1 and cars2

# %%
print(cars1.head())
cars2.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0  18.0          8           307        130    3504          12.0     70
# 1  15.0          8           350        165    3693          11.5     70
# 2  18.0          8           318        150    3436          11.0     70
# 3  16.0          8           304        150    3433          12.0     70
# 4  17.0          8           302        140    3449          10.5     70
#
#    origin                        car  Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# 0       1  chevrolet chevelle malibu         NaN          NaN          NaN
# 1       1          buick skylark 320         NaN          NaN          NaN
# 2       1         plymouth satellite         NaN          NaN          NaN
# 3       1              amc rebel sst         NaN          NaN          NaN
# 4       1                ford torino         NaN          NaN          NaN
#
#    Unnamed: 12  Unnamed: 13
# 0          NaN          NaN
# ...

# %% [markdown]
# ### Step 4. It seems our first dataset has some unnamed blank columns, fix cars1

# %%
cars1.loc[:,'mpg':'car']
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# ..    ...        ...           ...        ...     ...           ...    ...
# 193  24.0          6           200         81    3012          17.6     76
# 194  22.5          6           232         90    3085          17.6     76
# 195  29.0          4            85         52    2035          22.2     76
# 196  24.5          4            98         60    2164          22.1     76
# 197  29.0          4            90         70    1937          14.2     76
#
#      origin                        car
# ...

# %% [markdown]
# ### Step 5. What is the number of observations in each dataset?

# %%
cars1.shape
# Out:
# (198, 14)

# %%
cars2.shape
# Out:
# (200, 9)

# %% [markdown]
# ### Step 6. Join cars1 and cars2 into a single DataFrame called cars

# %%
cars = cars2.append(cars2)

# %%
cars
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    33.0          4            91         53    1795          17.4     76
# 1    20.0          6           225        100    3651          17.7     76
# 2    18.0          6           250         78    3574          21.0     76
# 3    18.5          6           250        110    3645          16.2     76
# 4    17.5          6           258         95    3193          17.8     76
# ..    ...        ...           ...        ...     ...           ...    ...
# 195  27.0          4           140         86    2790          15.6     82
# 196  44.0          4            97         52    2130          24.6     82
# 197  32.0          4           135         84    2295          11.6     82
# 198  28.0          4           120         79    2625          18.6     82
# 199  31.0          4           119         82    2720          19.4     82
#
#      origin                 car
# 0         3         honda civic
# ...

# %% [markdown]
# ### Step 7. There is a column missing, called owners. Create a random number Series from 15,000 to 73,000.

# %%
owners = random = np.random.randint(low=15000 , high=73001 , size =400 )

# %%
owners
# Out:
# array([36251, 49349, 51197, 35136, 34902, 25804, 17271, 60049, 57837,
#        17021, 67984, 26988, 33267, 52355, 63381, 20988, 71192, 62583,
#        20676, 26627, 26598, 71608, 45752, 37503, 25641, 63344, 49137,
#        44540, 34387, 53129, 62959, 24986, 24435, 49898, 71124, 69675,
#        62718, 68649, 37547, 34896, 40939, 27656, 33673, 41222, 65503,
#        46140, 24660, 68393, 43862, 20497, 35590, 63247, 33909, 42797,
#        23305, 39895, 61738, 56656, 40560, 26444, 26979, 52600, 48341,
#        25330, 44298, 55284, 41967, 68991, 38345, 39737, 39847, 28195,
#        40446, 55486, 72590, 70416, 50067, 40201, 31690, 57370, 28491,
#        53193, 65056, 43684, 67002, 42983, 70762, 68497, 54288, 51793,
#        63904, 51179, 33719, 22061, 35975, 67235, 68721, 67837, 40171,
#        17299, 32445, 53627, 47111, 53798, 68065, 21189, 19589, 39049,
#        59123, 46504, 72770, 42937, 59368, 62492, 38120, 65027, 71678,
# ...

# %% [markdown]
# ### Step 8. Add the column owners to cars

# %%
cars['owners'] = owners

# %%
cars.head(15)
# Out:
#      mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0   33.0          4            91         53    1795          17.4     76
# 1   20.0          6           225        100    3651          17.7     76
# 2   18.0          6           250         78    3574          21.0     76
# 3   18.5          6           250        110    3645          16.2     76
# 4   17.5          6           258         95    3193          17.8     76
# 5   29.5          4            97         71    1825          12.2     76
# 6   32.0          4            85         70    1990          17.0     76
# 7   28.0          4            97         75    2155          16.4     76
# 8   26.5          4           140         72    2565          13.6     76
# 9   20.0          4           130        102    3150          15.7     76
# 10  13.0          8           318        150    3940          13.2     76
# 11  19.0          4           120         88    3270          21.9     76
# ...
