# %%
#importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Importing data

# %%
Cus_Acq = pd.read_csv(r'C:\Users\prana\Desktop\Quarntine\AnalatyicsLab\Python\3._Case_Studies_Final_Projects_-_Python\4. Pandas Case Study 2 - Credit Card Case Study\Customer Acqusition.csv')

# %%
Cus_Acq.shape
# Out:
# (100, 8)

# %%
Cus_Acq.head(25)
# Out:
#     No Customer  Age       City   Product     Limit Company        Segment
# 0    1       A1   76  BANGALORE      Gold  500000.0      C1  Self Employed
# 1    2       A2   71   CALCUTTA    Silver  100000.0      C2   Salaried_MNC
# 2    3       A3   34     COCHIN  Platimum   10000.0      C3   Salaried_Pvt
# 3    4       A4   47     BOMBAY  Platimum   10001.0      C4           Govt
# 4    5       A5   56  BANGALORE  Platimum   10002.0      C5  Normal Salary
# 5    6       A6   70      DELHI    Silver  100000.0      C6  Self Employed
# 6    7       A7   26     COCHIN    Silver  100001.0      C7   Salaried_MNC
# 7    8       A8   67      PATNA    Silver  100002.0      C8   Salaried_Pvt
# 8    9       A9   79    CHENNAI    Silver  100003.0      C9           Govt
# 9   10      A10   54   CALCUTTA      Gold  500000.0     C10  Normal Salary
# 10  11      A11   35     COCHIN      Gold  500000.0     C11  Normal Salary
# ...

# %%
#a. In case age is less than 18, replace it with mean of age values
df = pd.DataFrame(Cus_Acq)
df.loc[df['Age']<18,'Age'] = Cus_Acq.Age.mean()
df.head(20)
# Out:
#     No Customer    Age       City   Product     Limit Company        Segment
# 0    1       A1  76.00  BANGALORE      Gold  500000.0      C1  Self Employed
# 1    2       A2  71.00   CALCUTTA    Silver  100000.0      C2   Salaried_MNC
# 2    3       A3  34.00     COCHIN  Platimum   10000.0      C3   Salaried_Pvt
# 3    4       A4  47.00     BOMBAY  Platimum   10001.0      C4           Govt
# 4    5       A5  56.00  BANGALORE  Platimum   10002.0      C5  Normal Salary
# 5    6       A6  70.00      DELHI    Silver  100000.0      C6  Self Employed
# 6    7       A7  26.00     COCHIN    Silver  100001.0      C7   Salaried_MNC
# 7    8       A8  67.00      PATNA    Silver  100002.0      C8   Salaried_Pvt
# 8    9       A9  79.00    CHENNAI    Silver  100003.0      C9           Govt
# 9   10      A10  54.00   CALCUTTA      Gold  500000.0     C10  Normal Salary
# 10  11      A11  35.00     COCHIN      Gold  500000.0     C11  Normal Salary
# ...

# %%
spend = pd.read_csv(r'C:\Users\prana\Desktop\Quarntine\AnalatyicsLab\Python\3._Case_Studies_Final_Projects_-_Python\4. Pandas Case Study 2 - Credit Card Case Study\spend.csv')

# %%
spend.shape
# Out:
# (1500, 5)

# %%
spend.head()
# Out:
#    Sl No: Customer      Month       Type     Amount
# 0       1       A1  12-Jan-04  JEWELLERY  485470.80
# 1       2       A1   3-Jan-04      PETRO  410556.13
# 2       3       A1  15-Jan-04    CLOTHES   23740.46
# 3       4       A1  25-Jan-04       FOOD  484342.47
# 4       5       A1  17-Jan-05     CAMERA  369694.07

# %%
cus_spend = pd.merge(left=Cus_Acq,right=spend,on='Customer')

# %%
df1 = cus_spend

# %%
cus_spend.shape
# Out:
# (1500, 12)

# %%
cus_spend.head(20)
# Out:
#     No Customer   Age       City Product     Limit Company        Segment  \
# 0    1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 1    1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 2    1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 3    1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 4    1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 5    1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 6    1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 7    1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 8    1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 9    1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 10   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 11   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# ...

# %%
#1b. In case spend amount is more than the limit, replace it with 50% of that customer’s limit.
#(customer’s limit provided in acquisition table is the per transaction limit on his card
lim = 0.5*cus_spend.Limit
cus_spend.loc[cus_spend['Amount']>cus_spend['Limit'],['Amount','Limit']] = lim
cus_spend.head()
# Out:
#    No Customer   Age       City Product     Limit Company        Segment  \
# 0   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 1   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 2   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 3   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 4   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
#
#    Sl No:      Month       Type     Amount
# 0       1  12-Jan-04  JEWELLERY  485470.80
# 1       2   3-Jan-04      PETRO  410556.13
# 2       3  15-Jan-04    CLOTHES   23740.46
# 3       4  25-Jan-04       FOOD  484342.47
# 4       5  17-Jan-05     CAMERA  369694.07

# %%
repay = pd.read_csv(r'C:\Users\prana\Desktop\Quarntine\AnalatyicsLab\Python\3._Case_Studies_Final_Projects_-_Python\4. Pandas Case Study 2 - Credit Card Case Study\Repayment.csv')

# %%
repay.head()
# Out:
#    SL No: Customer      Month     Amount  Unnamed: 4
# 0     NaN       A1  12-Jan-04  495414.75         NaN
# 1     2.0       A1   3-Jan-04  245899.02         NaN
# 2     3.0       A1  15-Jan-04  259490.06         NaN
# 3     4.0       A1  25-Jan-04  437555.12         NaN
# 4     5.0       A1  17-Jan-05  165972.88         NaN

# %%
repay.shape
# Out:
# (1523, 5)

# %%
df2 = cus_spend_rep = pd.merge(left=Cus_Acq,right=repay,on='Customer',how='inner')
#cus_spend_rep.drop(['Month_y','Amount_y'],axis=1,inplace=True)
cus_spend_rep.rename(columns={'Month_x':'Month','Amount_x':'Amount'},inplace=True)
df2
# Out:
#        No Customer   Age        City   Product     Limit Company  \
# 0       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# 1       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# 2       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# 3       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# 4       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# ...   ...      ...   ...         ...       ...       ...     ...
# 1495   96      A96  54.0     CHENNAI    Silver  100000.0     C19
# 1496   97      A97  58.0  TRIVANDRUM  Platimum   10000.0     C20
# 1497   98      A98  51.0    CALCUTTA  Platimum   10001.0     C21
# 1498   99      A99  35.0    CALCUTTA  Platimum   10002.0     C22
# 1499  100     A100  36.0      COCHIN    Silver  100000.0      C5
#
#             Segment  SL No:      Month     Amount  Unnamed: 4
# 0     Self Employed     NaN  12-Jan-04  495414.75         NaN
# ...

# %%
df2.isnull().sum()
# Out:
# No               0
# Customer         0
# Age              0
# City             0
# Product          0
# Limit            0
# Company          0
# Segment          0
# SL No:           1
# Month            0
# Amount           0
# Unnamed: 4    1500
# dtype: int64

# %%
#1c.Incase the repayment amount is more than the limit, replace the repayment with the limit.
df2.loc[df2['Amount']>df2['Limit'],['Amount','Limit']] = df2.Limit
df2
# Out:
#        No Customer   Age        City   Product     Limit Company  \
# 0       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# 1       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# 2       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# 3       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# 4       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# ...   ...      ...   ...         ...       ...       ...     ...
# 1495   96      A96  54.0     CHENNAI    Silver  100000.0     C19
# 1496   97      A97  58.0  TRIVANDRUM  Platimum   10000.0     C20
# 1497   98      A98  51.0    CALCUTTA  Platimum   10001.0     C21
# 1498   99      A99  35.0    CALCUTTA  Platimum   10002.0     C22
# 1499  100     A100  36.0      COCHIN    Silver  100000.0      C5
#
#             Segment  SL No:      Month     Amount  Unnamed: 4
# 0     Self Employed     NaN  12-Jan-04  495414.75         NaN
# ...

# %%
#2. From the above dataset create the following summaries:
#a. How many distinct customers exist?
df2.Customer.nunique()
# Out:
# 100

# %%
cus_spend.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1500 entries, 0 to 1499
# Data columns (total 12 columns):
# No          1500 non-null int64
# Customer    1500 non-null object
# Age         1500 non-null float64
# City        1500 non-null object
# Product     1500 non-null object
# Limit       1500 non-null float64
# Company     1500 non-null object
# Segment     1500 non-null object
# Sl No:      1500 non-null int64
# Month       1500 non-null object
# Type        1500 non-null object
# Amount      1500 non-null float64
# dtypes: float64(3), int64(2), object(7)
# memory usage: 192.3+ KB

# %%
#2b. How many distinct categories exist?
print("Product ",df.Product.nunique())
print("Segment ",df.Segment.nunique())
print("Type",cus_spend.Type.nunique())
# Out:
# Product  3
# Segment  5
# Type 15

# %%
#2c. What is the average monthly spend by customers?
cus_spend['Month'] = pd.to_datetime(cus_spend['Month'])
cus_spend['month'] = cus_spend['Month'].dt.month
Avg_spt = cus_spend.groupby(['Customer','month'])['Amount'].mean()
display(pd.DataFrame(Avg_spt))
# Out:
#                        Amount
# Customer month
# A1       1      372762.587143
#          2      175235.690000
#          4      261649.250000
#          5      361141.310000
#          8      344372.100000
# ...                       ...
# A95      1      240401.500000
# A96      1       54729.660000
# A97      1        5000.000000
# A98      1        5000.500000
# A99      1        5001.000000
#
# [578 rows x 1 columns]

# %%
#2d. What is the average monthly repayment by customers?
df2['Month'] = pd.to_datetime(df2['Month'])
df2['month'] = df2['Month'].dt.month
avg_month_repay = df2.groupby(["Customer","month"])['Amount'].mean()
display(pd.DataFrame(avg_month_repay))
# Out:
#                        Amount
# Customer month
# A1       1      343972.327143
#          2      156374.760000
#          4      254474.580000
#          7      297176.740000
#          9      186427.500000
# ...                       ...
# A95      1      369405.960000
# A96      1      100000.000000
# A97      1       10000.000000
# A98      1       10001.000000
# A99      1       10002.000000
#
# [558 rows x 1 columns]

# %%
#2e. If the monthly rate of interest is 2.9%, what is the profit for the bank for each month?
# (Profit is defined as interest earned on Monthly Profit. Monthly Profit = Monthly repayment
# – Monthly spend. Interest is earned only on positive profits and not on negative amounts)

profit = (df2['Amount']-cus_spend['Amount'])*0.029
df2['profit'] = profit
df2.loc[df2.profit<0,'profit']=0
profit_mon = df2.groupby(['month'])[['profit']].sum()
profit_mon.reset_index()
# Out:
#     month        profit
# 0       1  506186.45022
# 1       2  407811.52676
# 2       3  328218.40342
# 3       4  271071.57037
# 4       5  515042.79444
# 5       6   64419.50873
# 6       7   84895.48479
# 7       8   66102.39178
# 8       9   44349.39898
# 9      10   32785.78093
# 10     11  137937.39916
# 11     12   52058.55511

# %%
#2f. What are the top 5 product types?
top_5 = spend.groupby('Type').sum().sort_values("Amount",ascending=False)
top_5.reset_index().head()
# Out:
#            Type  Sl No:       Amount
# 0         PETRO  146920  49863174.09
# 1        CAMERA  113612  41481571.96
# 2          FOOD  110164  37773338.43
# 3  TRAIN TICKET   90087  33067077.15
# 4    AIR TICKET  117877  32955445.42

# %%
#2g. Which city is having maximum spend?
max_city_spn = cus_spend.groupby(['City'])['Amount'].sum()
max_city_spn.nlargest(3)
# Out:
# City
# COCHIN       45963513.50
# CALCUTTA     41108132.30
# BANGALORE    40461647.02
# Name: Amount, dtype: float64

# %%
#2h. Which age group is spending more money?
max_age = cus_spend.groupby(['Age']).sum()
max_age['Amount'].nlargest(2)
# Out:
# Age
# 28.00    17365270.23
# 46.49    15872551.38
# Name: Amount, dtype: float64

# %%
#i. Who are the top 10 customers in terms of repayment?
cust_10 = df2.groupby(['Customer']).sum().sort_values("Amount",ascending=False)
cust_10.head(10)
# Out:
#             No      Age       Limit   SL No:       Amount  Unnamed: 4  month  \
# Customer
# A61       2318  1672.00  19000000.0  45502.0  10539142.91         0.0    159
# A60       2280  1064.00  19000000.0  45464.0   9876290.74         0.0    146
# A13        403   899.00  15500000.0  10148.0   9572000.66         0.0    134
# A43       1333   651.00  15500000.0  31424.0   8489871.46         0.0    117
# A45       1395  2077.00  15500000.0  31486.0   8448334.87         0.0    119
# A12        372  1581.00  15500000.0  10117.0   8334760.16         0.0    123
# A14        434  1441.19  15500000.0  10179.0   7943268.63         0.0    137
# A44       1364   868.00  15500000.0  31455.0   7744730.12         0.0    126
# A39       1209  2418.00  15500000.0  31300.0   7622483.30         0.0    142
# A42       1302  1550.00  15500000.0  31393.0   7615460.86         0.0    115
#
#                 profit
# Customer
# A61       113626.92159
# A60        82409.15674
# A13        90518.75995
# ...

# %%
cus_spend.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1500 entries, 0 to 1499
# Data columns (total 13 columns):
# No          1500 non-null int64
# Customer    1500 non-null object
# Age         1500 non-null float64
# City        1500 non-null object
# Product     1500 non-null object
# Limit       1500 non-null float64
# Company     1500 non-null object
# Segment     1500 non-null object
# Sl No:      1500 non-null int64
# Month       1500 non-null datetime64[ns]
# Type        1500 non-null object
# Amount      1500 non-null float64
# month       1500 non-null int64
# dtypes: datetime64[ns](1), float64(3), int64(3), object(6)
# memory usage: 204.1+ KB

# %%
#3.Calculate the city wise spend on each product on yearly basis. Also include a graphical representation for the same.
cus_spend['year'] = cus_spend.Month.dt.year 
cus_spend.groupby(["City","Product","year"])[["Amount"]].sum()
# Out:
#                                Amount
# City       Product  year
# BANGALORE  Gold     2004   9289878.54
#                     2005  12892362.99
#                     2006  12030611.09
#            Platimum 2004   1112732.30
#                     2005    912284.97
# ...                               ...
# TRIVANDRUM Platimum 2005   3601443.30
#                     2006   2147403.75
#            Silver   2004    209667.48
#                     2005    269912.99
#                     2006    555862.12
#
# [72 rows x 1 columns]

# %%
pd.pivot_table(cus_spend, index =['City','Product'],columns ='year',values ='Amount').plot.bar(figsize=(12,6))
plt.ylabel('Total amount spend')
plt.show()

# %%
#4a. Monthly comparison of total spends, city wise

pd.pivot_table(cus_spend,index='City',columns='month',values='Amount').plot(kind='bar',figsize=(12,8))
#ax.legend(loc='upper center', bbox_to_anchor=(1.045,1), shadow=True, ncol=2)
plt.ylabel('Total amount spend')
# Out:
# Text(0, 0.5, 'Total amount spend')

# %%
#4b. Comparison of yearly spend on air tickets.
pd.pivot_table(cus_spend,index='Type',columns='year',values='Amount').iloc[[0]].plot(kind='bar',figsize=(12,8))

# %%
#4c.Comparison of monthly spend for each product (look for any seasonality that exists in terms of spend)
pd.pivot_table(cus_spend,index='Product',columns='month',values='Amount').plot(kind='bar',figsize=(12,6))
plt.legend()

# %%
# 5. Write user defined PYTHON function to perform the following analysis:
# You need to find top 10 customers for each city in terms of their repayment amount by
# different products and by different time periods i.e. year or month. The user should be able
# to specify the product (Gold/Silver/Platinum) and time period (yearly or monthly) and the
# function should automatically take these inputs while identifying the top 10 customers.


def top_customers():
    prod = input("Enter product name : ")
    time = input("Enter year  : ")
    df2['Month'] = pd.to_datetime(df2['Month'])
    df2['year'] = df2['Month'].dt.year
    df2['Month'] = df2['Month'].values.astype(str)

    if((df2[df2['year']==time]) and (df2[df2['Product']==prod])):
        return df2.groupby(['Customer','City']).sum().sort_values("Amount",ascending = False).head(10)

# %%
top_customers()
# Out:
# Enter product name : Gold
# Enter year  : 2004
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-27daf00c4b6a> in <module>
# ----> 1 top_customers()
#
# <ipython-input-38-752e675e7098> in top_customers()
#      13     df2['Month'] = df2['Month'].values.astype(str)
#      14
# ---> 15     if((df2[df2['year']==time]) and (df2[df2['Product']==prod])):
#      16         return df2.groupby(['Customer','City']).sum().sort_values("Amount",ascending = False).head(10)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1553             "The truth value of a {0} is ambiguous. "
#    1554             "Use a.empty, a.bool(), a.item(), a.any() or a.all().".format(
# -> 1555                 self.__class__.__name__
#    1556             )
#    1557         )
#
# ...
