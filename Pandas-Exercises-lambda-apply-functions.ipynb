# %% [markdown]
# # Student Alcohol Consumption

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the datasets *student-mat* and *student-por* and merge them.

# %%
data = pd.read_csv(r'C:\Users\prana\Desktop\Quarntine\AnalatyicsLab\Python\3._Case_Studies_Final_Projects_-_Python\2. Pandas Basic Exercises\Exercise Data Files\Pandas Exercise Lambda Functions Files\student-mat.csv')
data1 = pd.read_csv(r'C:\Users\prana\Desktop\Quarntine\AnalatyicsLab\Python\3._Case_Studies_Final_Projects_-_Python\2. Pandas Basic Exercises\Exercise Data Files\Pandas Exercise Lambda Functions Files\student-por.csv')

# %%
data.shape
# Out:
# (395, 33)

# %%
data1.shape
# Out:
# (649, 33)

# %%
pd.concat([data,data1])
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %% [markdown]
# ### Step 3. Assign it to a variable called df.

# %%
df = pd.concat([data,data1])
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %% [markdown]
# ### Step 4. For the purpose of this exercise slice the dataframe from 'school' until the 'guardian' column

# %%
stal = df.loc[:, "school":"guardian"]
stal
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
#      reason guardian
# 0    course   mother
# ...

# %% [markdown]
# ### Step 5. Create a lambda function that captalize strings.

# %%
cap = lambda x : x.capitalize()

# %% [markdown]
# ### Step 6. Capitalize both Mjob and Fjob

# %%
stal['Mjob'].apply(cap)
stal['Fjob'].apply(cap)
# Out:
# 0       Teacher
# 1         Other
# 2         Other
# 3      Services
# 4         Other
#          ...
# 644       Other
# 645    Services
# 646       Other
# 647    Services
# 648       Other
# Name: Fjob, Length: 1044, dtype: object

# %% [markdown]
# ### Step 7. Print the last elements of the data set.

# %%
stal.tail()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
#      reason guardian
# 644  course   mother
# 645  course   mother
# 646  course   mother
# 647  course   mother
# 648  course   mother

# %% [markdown]
# ### Step 8. Did you notice the original dataframe is still lowercase? Why is that? Fix it and captalize Mjob and Fjob.

# %%
stal['Mjob'] = stal['Mjob'].apply(cap)
stal['Fjob'] = stal['Fjob'].apply(cap)
stal.tail()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 644     MS   F   19       R     GT3       T     2     3  Services     Other
# 645     MS   F   18       U     LE3       T     3     1   Teacher  Services
# 646     MS   F   18       U     GT3       T     1     1     Other     Other
# 647     MS   M   17       U     LE3       T     3     1  Services  Services
# 648     MS   M   18       R     LE3       T     3     2  Services     Other
#
#      reason guardian
# 644  course   mother
# 645  course   mother
# 646  course   mother
# 647  course   mother
# 648  course   mother

# %% [markdown]
# # Step 9. Create a function called majority that return a boolean value to a new column called legal_drinker

# %%
def majority(x):
    if x > 17:
        return True
    else:
        return False

# %%
stal['Legal_Drinker'] = stal['age'].apply(majority)
stal.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4  At_home   Teacher
# 1     GP   F   17       U     GT3       T     1     1  At_home     Other
# 2     GP   F   15       U     LE3       T     1     1  At_home     Other
# 3     GP   F   15       U     GT3       T     4     2   Health  Services
# 4     GP   F   16       U     GT3       T     3     3    Other     Other
#
#    reason guardian  Legal_Drinker
# 0  course   mother           True
# 1  course   father          False
# 2   other   mother          False
# 3    home   mother          False
# 4    home   father          False

# %% [markdown]
# ### Step 10. Multiply every number of the dataset by 10.

# %%
def time(x):
    if type(x) is int:
        return 10 * x
    return x

# %%
stal.apply(time).head(15)
# Out:
#    school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0      GP   F   18       U     GT3       A     4     4   At_home   Teacher
# 1      GP   F   17       U     GT3       T     1     1   At_home     Other
# 2      GP   F   15       U     LE3       T     1     1   At_home     Other
# 3      GP   F   15       U     GT3       T     4     2    Health  Services
# 4      GP   F   16       U     GT3       T     3     3     Other     Other
# 5      GP   M   16       U     LE3       T     4     3  Services     Other
# 6      GP   M   16       U     LE3       T     2     2     Other     Other
# 7      GP   F   17       U     GT3       A     4     4     Other   Teacher
# 8      GP   M   15       U     LE3       A     3     2  Services     Other
# 9      GP   M   15       U     GT3       T     3     4     Other     Other
# 10     GP   F   15       U     GT3       T     4     4   Teacher    Health
# ...
